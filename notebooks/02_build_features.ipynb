# %%
import os, sys
sys.path.append(os.path.abspath(".."))
from src.fe import build_and_save_features

features = build_and_save_features("../data/raw/games_2024_regular.csv", season=2024)
print(features.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 5
#       2 sys.path.append(os.path.abspath(".."))
#       3 from src.fe import build_and_save_features
# ----> 5 features = build_and_save_features("../data/raw/games_2024_regular.csv", season=2024)
#       6 print(features.head(10))
#
# File c:\Users\palle\source\repos\cfp-predictor\src\fe.py:93, in build_and_save_features(games_path, season, rolling_window)
#      91 def build_and_save_features(games_path: str, season: int, rolling_window: int = 3):
#      92     df = pd.read_csv(games_path)
# ---> 93     features = build_team_week_features(df, season, rolling_window)
#      94     out_path = FEATURE_DIR / f"team_week_features_{season}.parquet"
#      95     features.to_parquet(out_path, index=False)
#
# ...
