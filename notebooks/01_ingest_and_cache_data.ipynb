# %%
import os, sys
from dotenv import load_dotenv
sys.path.append(os.path.abspath(".."))
load_dotenv()

print("CFBD key loaded:", os.getenv("CFBD_API_KEY")[:10], "...")
from src.ingest_cfbd import CFBDClient

cfbd = CFBDClient()
df = cfbd.get_games(2025)
print(df.head())
# Out:
# CFBD key loaded: 1vEC8UkhGs ...
#           id  season  week seasonType                 startDate  startTimeTBD  \
# 0  401693677    2024     1    regular  2024-08-24T04:00:00.000Z          True
# 1  401635525    2024     1    regular  2024-08-24T16:00:00.000Z         False
# 2  401654665    2024     1    regular  2024-08-24T19:30:00.000Z         False
# 3  401643697    2024     1    regular  2024-08-24T20:00:00.000Z         False
# 4  401654662    2024     1    regular  2024-08-24T23:00:00.000Z         False
#
#    completed  neutralSite  conferenceGame  attendance  ...  \
# 0       True         True           False         NaN  ...
# 1       True         True            True     47998.0  ...
# 2       True        False           False     16125.0  ...
# 3       True        False           False     17314.0  ...
# 4       True         True           False      4358.0  ...
#
#    awayClassification awayConference  awayPoints   awayLineScores  \
# ...
